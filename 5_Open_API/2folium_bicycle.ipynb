# %% [markdown]
# ## 데이터불러오기

# %%
import pandas as pd

# %%
file = './data/bicycle.xlsx'
data = pd.read_excel(file)
data.head()
# Out:
#    Unnamed: 0  rackTotCnt      stationName  parkingBikeTotCnt  shared  \
# 0           0          22  102. 망원역 1번출구 앞                 26     118
# 1           1          16  103. 망원역 2번출구 앞                 12      75
# 2           2          15  104. 합정역 1번출구 앞                  8      53
# 3           3           7  105. 합정역 5번출구 앞                  0       0
# 4           4          12  106. 합정역 7번출구 앞                  8      67
#
#    stationLatitude  stationLongitude stationId
# 0        37.555649        126.910629      ST-4
# 1        37.554951        126.910835      ST-5
# 2        37.550629        126.914986      ST-6
# 3        37.550007        126.914825      ST-7
# 4        37.548645        126.912827      ST-8

# %% [markdown]
# ## 지도 시각화

# %%
import folium

# %%
# N서울타워 : [37.551254438970005, 126.98818368273312]
m = folium.Map(location = [37.551254438970005, 126.98818368273312], zoom_start=13)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
data.index
# Out:
# RangeIndex(start=0, stop=2000, step=1)

# %%
for i in data.index:
    lat = data.loc[i,'stationLatitude']
    long = data.loc[i,'stationLongitude']
    name = data.loc[i,'stationName']
    available = data.loc[i, 'parkingBikeTotCnt']
    total = data.loc[i, 'rackTotCnt']
    print(name,available,total, lat, long)
# Out:
# 102. 망원역 1번출구 앞 26 22 37.5556488 126.91062927
# 103. 망원역 2번출구 앞 12 16 37.55495071 126.91083527
# 104. 합정역 1번출구 앞 8 15 37.55062866 126.91498566
# 105. 합정역 5번출구 앞 0 7 37.55000687 126.91482544
# 106. 합정역 7번출구 앞 8 12 37.54864502 126.91282654
# 107. 신한은행 서교동금융센터점 앞 21 7 37.55751038 126.91850281
# 108. 서교동 사거리 9 12 37.55274582 126.91861725
# 109. 제일빌딩 앞 13 12 37.54769135 126.91998291
# 111. 상수역 2번출구 앞 10 12 37.54787064 126.92353058
# 112. 극동방송국 앞 19 12 37.54920197 126.92320251
# 113. 홍대입구역 2번출구 앞 23 25 37.55749893 126.92380524
# 114. 홍대입구역 8번출구 앞 34 17 37.55706024 126.92442322
# 115. 마스타 빌딩 앞 14 15 37.55893326 126.92711639
# 116. 일진아이윌아파트 옆 3 7 37.56454086 126.92707062
# 117. 홍은사거리 5 27 37.59115982 126.94132996
# 118. 광흥창역 2번출구 앞 11 11 37.54773331 126.9317627
# 119. 서강나루 공원 7 12 37.54528427 126.93105316
# 120. 신수동 사거리 6 7 37.54524231 126.93411255
# 121. 마포소방서 앞 9 17 37.54976654 126.93317413
# 122. 신성기사식당 앞 6 12 37.54745865 126.93837738
# 123. 문화촌 공원 15 22 37.59432983 126.9473877
# ...

# %% [markdown]
# ## 따릉이 지도 만들기 1

# %%
# N서울타워 : [37.551254438970005, 126.98818368273312]
m = folium.Map(location = [37.551254438970005, 126.98818368273312], zoom_start=11)

for i in data.index:
    lat = data.loc[i,'stationLatitude']
    long = data.loc[i,'stationLongitude']
    name = data.loc[i,'stationName']
    available = data.loc[i, 'parkingBikeTotCnt']
    total = data.loc[i, 'rackTotCnt']
    
    folium.Marker(location=[lat,long],tooltip=f'{name} : {available}').add_to(m)
    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# 마커가 너무 많습니다... 다른 방법으로 그려보도록 합시다.
# <br>자전거의 수량에 따라 다르게 마커를 해봅니다.

# %%
# N서울타워 : [37.551254438970005, 126.98818368273312]
m = folium.Map(location = [37.551254438970005, 126.98818368273312], zoom_start=12)

for i in data.index:
    lat = data.loc[i,'stationLatitude']
    long = data.loc[i,'stationLongitude']
    name = data.loc[i,'stationName']
    available = data.loc[i, 'parkingBikeTotCnt']
    total = data.loc[i, 'rackTotCnt']
    
    if available / total > 0.5:
        color = 'blue'
    elif available < 2:
        color = 'red'
    else:
        color = 'green'
        
    icon = folium.Icon(color= color, icon='info-sign')
    
    folium.Marker(location=[lat,long],tooltip=f'{name} : {available}', icon=icon).add_to(m)
    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
